# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_cities.csv")
rain_df.head()
# Out:
#         LOCATION  Millimetres  Inches
# 0       Adelaide          547   21.54
# 1  Alice Springs          291   11.46
# 2       Brisbane         1080   42.52
# 3         Broome          658   25.91
# 4         Cairns         1982   78.03

# %%
# Set x axis and tick locations

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
# Out:
# <img src="data:image/png;base64,..." width="800">
# ([<matplotlib.axis.XTick at 0x7fd0d1d9e0b0>,
#   <matplotlib.axis.XTick at 0x7fd0d1d9e080>,
#   <matplotlib.axis.XTick at 0x7fd0d1d9df60>,
#   <matplotlib.axis.XTick at 0x7fd0f0950460>,
#   <matplotlib.axis.XTick at 0x7fd0f0950bb0>,
#   <matplotlib.axis.XTick at 0x7fd0f0951300>,
#   <matplotlib.axis.XTick at 0x7fd0f0951a50>,
#   <matplotlib.axis.XTick at 0x7fd0f09522c0>,
#   <matplotlib.axis.XTick at 0x7fd0f0951060>,
#   <matplotlib.axis.XTick at 0x7fd0f09523e0>,
#   <matplotlib.axis.XTick at 0x7fd0f0952b30>,
#   <matplotlib.axis.XTick at 0x7fd0f0953280>],
#  [Text(0, 0, 'Adelaide'),
#   Text(1, 0, 'Alice Springs'),
#   Text(2, 0, 'Brisbane'),
#   Text(3, 0, 'Broome'),
#   Text(4, 0, 'Cairns'),
#   Text(5, 0, 'Canberra'),
#   Text(6, 0, 'Darwin'),
#   Text(7, 0, 'Hobart'),
#   Text(8, 0, 'Melbourne'),
#   Text(9, 0, 'Perth'),
#   Text(10, 0, 'Sydney'),
#   Text(11, 0, 'Townsville')])

# %%
# Set x and y limits
# Out:
# (0.0, 2032.0)

# %%
# Set a Title and labels
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Millimetres')

# %%
# Save our graph and show the grap

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart

# Set the index to be "State" so they will be used as labels
# Out:
#                Millimetres
# LOCATION
# Adelaide               547
# Alice Springs          291
# Brisbane              1080
# Broome                 658
# Cairns                1982

# %%
# Use DataFrame.plot() in order to create a bar chart of the data

# Set a title for the chart
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
# Out:
# <img src="data:image/png;base64,..." width="800">
